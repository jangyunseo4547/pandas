# %%
import pandas as pd

df1 = pd.read_csv('data/sales_data1.csv')
df2 = pd.read_csv('data/sales_data1.csv')

# %%
df1.head()
# Out:
#    index  Transaction ID        Date Product Category  \
# 0      0           10001  2024-01-01      Electronics
# 1      1           10002  2024-01-02  Home Appliances
# 2      2           10003  2024-01-03         Clothing
# 3      3           10004  2024-01-04            Books
# 4      4           10005  2024-01-05  Beauty Products
#
#               Product Name  Units Sold  Unit Price  Total Revenue  \
# 0            iPhone 14 Pro           2      999.99        1999.98
# 1         Dyson V11 Vacuum           1      499.99         499.99
# 2         Levi's 501 Jeans           3       69.99         209.97
# 3        The Da Vinci Code           4       15.99          63.96
# 4  Neutrogena Skincare Set           1       89.99          89.99
#
#           Region Payment Method
# 0  North America    Credit Card
# 1         Europe         PayPal
# 2           Asia     Debit Card
# 3  North America    Credit Card
# 4         Europe         PayPal

# %%
df1.shape
# Out:
# (182, 10)

# %%
df2.shape
# Out:
# (182, 10)

# %% [markdown]
# ## 1. concat()

# %%
#pd.concat([df1, df2]).iloc[170:190]

pd.concat([df1, df2],ignore_index = True)
# Out:
#      index  Transaction ID        Date Product Category  \
# 0        0           10001  2024-01-01      Electronics
# 1        1           10002  2024-01-02  Home Appliances
# 2        2           10003  2024-01-03         Clothing
# 3        3           10004  2024-01-04            Books
# 4        4           10005  2024-01-05  Beauty Products
# ..     ...             ...         ...              ...
# 359    177           10178  2024-06-26            Books
# 360    178           10179  2024-06-27  Beauty Products
# 361    179           10180  2024-06-28           Sports
# 362    180           10181  2024-06-29      Electronics
# 363    181           10182  2024-06-30  Home Appliances
#
#                                Product Name  Units Sold  Unit Price  \
# 0                             iPhone 14 Pro           2      999.99
# 1                          Dyson V11 Vacuum           1      499.99
# 2                          Levi's 501 Jeans           3       69.99
# 3                         The Da Vinci Code           4       15.99
# 4                   Neutrogena Skincare Set           1       89.99
# ..                                      ...         ...         ...
# 359  The Sun Also Rises by Ernest Hemingway           3       11.99
# 360     First Aid Beauty Ultra Repair Cream           2       34.00
# 361              Oakley Holbrook Sunglasses           1      146.00
# 362                     Google Pixelbook Go           1      649.99
# 363                       Dyson V8 Absolute           1      399.99
#
#      Total Revenue         Region Payment Method
# 0          1999.98  North America    Credit Card
# 1           499.99         Europe         PayPal
# 2           209.97           Asia     Debit Card
# 3            63.96  North America    Credit Card
# 4            89.99         Europe         PayPal
# ..             ...            ...            ...
# 359          35.97  North America    Credit Card
# 360          68.00         Europe         PayPal
# 361         146.00           Asia    Credit Card
# 362         649.99  North America    Credit Card
# 363         399.99         Europe         PayPal
#
# [364 rows x 10 columns]

# %%
sales1 = df1.iloc[:, :5] #전체 인덱스를 가져오고, 0~5번까지의 컬럼을 가져옴
sales2 = df2.iloc[:, 5:]

# %%
sales1.info() #5개의 컬럼만 남아있음을 볼 수 있음.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             182 non-null    int64
#  1   Transaction ID    182 non-null    int64
#  2   Date              182 non-null    object
#  3   Product Category  182 non-null    object
#  4   Product Name      182 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 7.2+ KB

# %%
sales2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Units Sold      182 non-null    int64
#  1   Unit Price      182 non-null    float64
#  2   Total Revenue   182 non-null    float64
#  3   Region          182 non-null    object
#  4   Payment Method  182 non-null    object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 7.2+ KB

# %%
pd.concat([sales1, sales2], axis = 1) # axis = 좌우로 연결
# Out:
#      index  Transaction ID        Date Product Category  \
# 0        0           10001  2024-01-01      Electronics
# 1        1           10002  2024-01-02  Home Appliances
# 2        2           10003  2024-01-03         Clothing
# 3        3           10004  2024-01-04            Books
# 4        4           10005  2024-01-05  Beauty Products
# ..     ...             ...         ...              ...
# 177    177           10178  2024-06-26            Books
# 178    178           10179  2024-06-27  Beauty Products
# 179    179           10180  2024-06-28           Sports
# 180    180           10181  2024-06-29      Electronics
# 181    181           10182  2024-06-30  Home Appliances
#
#                                Product Name  Units Sold  Unit Price  \
# 0                             iPhone 14 Pro           2      999.99
# 1                          Dyson V11 Vacuum           1      499.99
# 2                          Levi's 501 Jeans           3       69.99
# 3                         The Da Vinci Code           4       15.99
# 4                   Neutrogena Skincare Set           1       89.99
# ..                                      ...         ...         ...
# 177  The Sun Also Rises by Ernest Hemingway           3       11.99
# 178     First Aid Beauty Ultra Repair Cream           2       34.00
# 179              Oakley Holbrook Sunglasses           1      146.00
# 180                     Google Pixelbook Go           1      649.99
# 181                       Dyson V8 Absolute           1      399.99
#
#      Total Revenue         Region Payment Method
# 0          1999.98  North America    Credit Card
# 1           499.99         Europe         PayPal
# 2           209.97           Asia     Debit Card
# 3            63.96  North America    Credit Card
# 4            89.99         Europe         PayPal
# ..             ...            ...            ...
# 177          35.97  North America    Credit Card
# 178          68.00         Europe         PayPal
# 179         146.00           Asia    Credit Card
# 180         649.99  North America    Credit Card
# 181         399.99         Europe         PayPal
#
# [182 rows x 10 columns]

# %% [markdown]
# ## 2. merge
# - 정규화 : 단일 데이터로 유지할 수 있게 함.
#   - 데이터가 독립적일때 merge를 활용해 병합 : 두 데이터의 교집합만 남음.
#     - how = 'inner', left, right, outer

# %%
info = {
    '고객명': ['박세리', '이대호', '손흥민', '김연아', '마이클조던'],
    '생년월일': ['1980-01-02', '1982-02-22', '1993-06-12', '1988-10-16', '1970-03-03'],
    '성별': ['여자', '남자', '남자', '여자', '남자']
}

money = {
    '고객명': ['김연아', '박세리', '손흥민', '이대호', '타이거우즈'],
    '연봉': ['2000원', '3000원', '1500원', '2500원', '3500원']
}

# %%
df1 = pd.DataFrame(info)
df2 = pd.DataFrame(money)

# %%
df1
# Out:
#      고객명        생년월일  성별
# 0    박세리  1980-01-02  여자
# 1    이대호  1982-02-22  남자
# 2    손흥민  1993-06-12  남자
# 3    김연아  1988-10-16  여자
# 4  마이클조던  1970-03-03  남자

# %%
df2
# Out:
#      고객명     연봉
# 0    김연아  2000원
# 1    박세리  3000원
# 2    손흥민  1500원
# 3    이대호  2500원
# 4  타이거우즈  3500원

# %%
# 교집합 (inner merge) 선택

pd.merge(df1, df2)
# Out:
#    고객명        생년월일  성별     연봉
# 0  박세리  1980-01-02  여자  3000원
# 1  이대호  1982-02-22  남자  2500원
# 2  손흥민  1993-06-12  남자  1500원
# 3  김연아  1988-10-16  여자  2000원

# %%
#1) 교집합

pd.merge(df1, df2, how = 'inner')
# Out:
#    고객명        생년월일  성별     연봉
# 0  박세리  1980-01-02  여자  3000원
# 1  이대호  1982-02-22  남자  2500원
# 2  손흥민  1993-06-12  남자  1500원
# 3  김연아  1988-10-16  여자  2000원

# %%
# 2) 합집합 : 없는 데이터는 nan으로 채워줌

pd.merge(df1, df2, how = 'outer')
# Out:
#      고객명        생년월일   성별     연봉
# 0    김연아  1988-10-16   여자  2000원
# 1  마이클조던  1970-03-03   남자    NaN
# 2    박세리  1980-01-02   여자  3000원
# 3    손흥민  1993-06-12   남자  1500원
# 4    이대호  1982-02-22   남자  2500원
# 5  타이거우즈         NaN  NaN  3500원

# %%
# 3) left, right

# pd.merge(df1,df2, how = 'left')
pd.merge(df1,df2, how = 'right')
# Out:
#      고객명        생년월일   성별     연봉
# 0    김연아  1988-10-16   여자  2000원
# 1    박세리  1980-01-02   여자  3000원
# 2    손흥민  1993-06-12   남자  1500원
# 3    이대호  1982-02-22   남자  2500원
# 4  타이거우즈         NaN  NaN  3500원

# %%
# 인덱스의 이름이 다른 경우 merge

info = {
    '이름': ['박세리', '이대호', '손흥민', '김연아', '마이클조던'],
    '생년월일': ['1980-01-02', '1982-02-22', '1993-06-12', '1988-10-16', '1970-03-03'],
    '성별': ['여자', '남자', '남자', '여자', '남자']
}

money = {
    '고객명': ['김연아', '박세리', '손흥민', '이대호', '타이거우즈'],
    '연봉': ['2000원', '3000원', '1500원', '2500원', '3500원']
}

# %%
df1 = pd.DataFrame(info)
df2 = pd.DataFrame(money)

# %%
pd.merge(df1,df2, left_on = '이름', right_on = '고객명')
# Out:
#     이름        생년월일  성별  고객명     연봉
# 0  박세리  1980-01-02  여자  박세리  3000원
# 1  이대호  1982-02-22  남자  이대호  2500원
# 2  손흥민  1993-06-12  남자  손흥민  1500원
# 3  김연아  1988-10-16  여자  김연아  2000원

# %% [markdown]
# ### 연습 3

# %%
movies = pd.read_csv('data/movies.csv')
reviews = pd.read_csv('data/reviews.csv')

# %%
movies.head()
# Out:
#                                 movieId  \
# 0  4517f650-c60a-4edc-b37e-9236213c2b93
# 1  9ddacc49-1918-3722-b5d9-4a1fa6b9b2a3
# 2  e1374d4d-19b0-31b2-a6cc-c4189f2b27ca
# 3  27539355-4940-4c29-aaab-d3fe4dafa4ee
# 4  2da44bd6-2a22-3238-a139-a40ab1769550
#
#                                     movieTitle  movieYear  \
# 0            Spider-Man: Into the Spider-Verse       2018
# 1                              The Incredibles       2004
# 2                                Black Panther       2018
# 3          Spider-Man: Across the Spider-Verse       2023
# 4  Teenage Mutant Ninja Turtles: Mutant Mayhem       2023
#
#                                             movieURL  movieRank critic_score  \
# 0  https://www.rottentomatoes.com/m/spider_man_in...          1          97%
# 1   https://www.rottentomatoes.com/m/the_incredibles          2          97%
# 2  https://www.rottentomatoes.com/m/black_panther...          3          96%
# 3  https://www.rottentomatoes.com/m/spider_man_ac...          4          95%
# 4  https://www.rottentomatoes.com/m/teenage_mutan...          5          95%
#
#   audience_score
# 0            94%
# 1            75%
# 2            79%
# 3            94%
# 4            90%

# %%
reviews.head()
# Out:
#                                 movieId  rating  \
# 0  df35d67b-c89e-30fa-bff5-c31006cc6ae4     5.0
# 1  df35d67b-c89e-30fa-bff5-c31006cc6ae4     4.0
# 2  df35d67b-c89e-30fa-bff5-c31006cc6ae4     2.0
# 3  e70c15a3-eb05-3f65-9988-a1787615d464     5.0
# 4  f03e65c8-70e8-34e2-bd3f-1a2efd916f3a     4.0
#
#                                                quote reviewId  isVerified  \
# 0  A decent sequel that leaves the door open for ...      NaN       False
# 1                           What smells like sulfur?      NaN       False
# 2                          dissappointing and stupid      NaN       False
# 3  Less campy villains than the first (discountin...      NaN       False
# 4           Finally!  One worth watching over again!      NaN       False
#
#    isSuperReviewer  hasSpoilers  hasProfanity  score creationDate  \
# 0            False        False         False    5.0   2006-02-10
# 1            False        False         False    4.0   2006-02-10
# 2            False        False         False    2.0   2006-02-10
# 3            False        False         False    5.0   2006-02-10
# 4            False        False         False    4.0   2006-02-10
#
#    userDisplayName userRealm    userId
# 0              NaN        RT  34988849
# 1              NaN        RT  25114980
# 2              NaN        RT  13536103
# 3              NaN        RT  38236390
# 4              NaN        RT  23716534

# %%
movie_review = pd.merge(movies, reviews)

# %%
movie_review.head(5)
# Out:
#                                 movieId     movieTitle  movieYear  \
# 0  a5479658-16f1-3325-a16a-4181d84a215a        RoboCop       1987
# 1  a5479658-16f1-3325-a16a-4181d84a215a        RoboCop       1987
# 2  f03e65c8-70e8-34e2-bd3f-1a2efd916f3a  Batman Begins       2005
# 3  f03e65c8-70e8-34e2-bd3f-1a2efd916f3a  Batman Begins       2005
# 4  f03e65c8-70e8-34e2-bd3f-1a2efd916f3a  Batman Begins       2005
#
#                                            movieURL  movieRank critic_score  \
# 0  https://www.rottentomatoes.com/m/1017712-robocop         19          92%
# 1  https://www.rottentomatoes.com/m/1017712-robocop         19          92%
# 2    https://www.rottentomatoes.com/m/batman_begins         41          85%
# 3    https://www.rottentomatoes.com/m/batman_begins         41          85%
# 4    https://www.rottentomatoes.com/m/batman_begins         41          85%
#
#   audience_score  rating                                              quote  \
# 0            84%     4.0                  Nasty 80s sci-fi, pretty exciting
# 1            84%     5.0  OH MAN! POSSIBLY ONE OF THE BEST FILMS IVE EVE...
# 2            94%     4.0           Finally!  One worth watching over again!
# 3            94%     1.0  I know it's abotu batman and all, but this mov...
# 4            94%     5.0                      The best Batman movie to date
#
#   reviewId  isVerified  isSuperReviewer  hasSpoilers  hasProfanity  score  \
# 0      NaN       False            False        False         False    4.0
# 1      NaN       False            False        False         False    5.0
# 2      NaN       False            False        False         False    4.0
# 3      NaN       False            False        False         False    1.0
# 4      NaN       False            False        False         False    5.0
#
#   creationDate  userDisplayName userRealm    userId
# 0   2006-02-11              NaN        RT  19964219
# 1   2006-02-11              NaN        RT  47687302
# 2   2006-02-10              NaN        RT  23716534
# 3   2006-02-10              NaN        RT  37225455
# 4   2006-02-10              NaN        RT  39217567

# %%
cond = movie_review['movieYear'] == 2005
movie_review.loc[cond]
# Out:
#                                  movieId     movieTitle  movieYear  \
# 2   f03e65c8-70e8-34e2-bd3f-1a2efd916f3a  Batman Begins       2005
# 3   f03e65c8-70e8-34e2-bd3f-1a2efd916f3a  Batman Begins       2005
# 4   f03e65c8-70e8-34e2-bd3f-1a2efd916f3a  Batman Begins       2005
# 5   f03e65c8-70e8-34e2-bd3f-1a2efd916f3a  Batman Begins       2005
# 6   f03e65c8-70e8-34e2-bd3f-1a2efd916f3a  Batman Begins       2005
# 7   f03e65c8-70e8-34e2-bd3f-1a2efd916f3a  Batman Begins       2005
# 8   f03e65c8-70e8-34e2-bd3f-1a2efd916f3a  Batman Begins       2005
# 9   f03e65c8-70e8-34e2-bd3f-1a2efd916f3a  Batman Begins       2005
# 10  f03e65c8-70e8-34e2-bd3f-1a2efd916f3a  Batman Begins       2005
# 11  f03e65c8-70e8-34e2-bd3f-1a2efd916f3a  Batman Begins       2005
# 12  f03e65c8-70e8-34e2-bd3f-1a2efd916f3a  Batman Begins       2005
# 13  f03e65c8-70e8-34e2-bd3f-1a2efd916f3a  Batman Begins       2005
# 14  f03e65c8-70e8-34e2-bd3f-1a2efd916f3a  Batman Begins       2005
# 15  f03e65c8-70e8-34e2-bd3f-1a2efd916f3a  Batman Begins       2005
# 16  f03e65c8-70e8-34e2-bd3f-1a2efd916f3a  Batman Begins       2005
# 17  f03e65c8-70e8-34e2-bd3f-1a2efd916f3a  Batman Begins       2005
# 18  f03e65c8-70e8-34e2-bd3f-1a2efd916f3a  Batman Begins       2005
# 19  f03e65c8-70e8-34e2-bd3f-1a2efd916f3a  Batman Begins       2005
# 20  f03e65c8-70e8-34e2-bd3f-1a2efd916f3a  Batman Begins       2005
# 21  f03e65c8-70e8-34e2-bd3f-1a2efd916f3a  Batman Begins       2005
# 22  f03e65c8-70e8-34e2-bd3f-1a2efd916f3a  Batman Begins       2005
# 23  f03e65c8-70e8-34e2-bd3f-1a2efd916f3a  Batman Begins       2005
# 24  f03e65c8-70e8-34e2-bd3f-1a2efd916f3a  Batman Begins       2005
# 25  f03e65c8-70e8-34e2-bd3f-1a2efd916f3a  Batman Begins       2005
# 26  f03e65c8-70e8-34e2-bd3f-1a2efd916f3a  Batman Begins       2005
# 53  f3d4d7d9-1a2c-37bc-b663-682e01ea1fbf       Sky High       2005
# 54  f3d4d7d9-1a2c-37bc-b663-682e01ea1fbf       Sky High       2005
# 55  f3d4d7d9-1a2c-37bc-b663-682e01ea1fbf       Sky High       2005
# 56  f3d4d7d9-1a2c-37bc-b663-682e01ea1fbf       Sky High       2005
#
#                                              movieURL  movieRank critic_score  \
# 2      https://www.rottentomatoes.com/m/batman_begins         41          85%
# 3      https://www.rottentomatoes.com/m/batman_begins         41          85%
# 4      https://www.rottentomatoes.com/m/batman_begins         41          85%
# 5      https://www.rottentomatoes.com/m/batman_begins         41          85%
# 6      https://www.rottentomatoes.com/m/batman_begins         41          85%
# 7      https://www.rottentomatoes.com/m/batman_begins         41          85%
# 8      https://www.rottentomatoes.com/m/batman_begins         41          85%
# 9      https://www.rottentomatoes.com/m/batman_begins         41          85%
# 10     https://www.rottentomatoes.com/m/batman_begins         41          85%
# 11     https://www.rottentomatoes.com/m/batman_begins         41          85%
# 12     https://www.rottentomatoes.com/m/batman_begins         41          85%
# 13     https://www.rottentomatoes.com/m/batman_begins         41          85%
# 14     https://www.rottentomatoes.com/m/batman_begins         41          85%
# 15     https://www.rottentomatoes.com/m/batman_begins         41          85%
# 16     https://www.rottentomatoes.com/m/batman_begins         41          85%
# 17     https://www.rottentomatoes.com/m/batman_begins         41          85%
# 18     https://www.rottentomatoes.com/m/batman_begins         41          85%
# 19     https://www.rottentomatoes.com/m/batman_begins         41          85%
# 20     https://www.rottentomatoes.com/m/batman_begins         41          85%
# 21     https://www.rottentomatoes.com/m/batman_begins         41          85%
# 22     https://www.rottentomatoes.com/m/batman_begins         41          85%
# 23     https://www.rottentomatoes.com/m/batman_begins         41          85%
# 24     https://www.rottentomatoes.com/m/batman_begins         41          85%
# 25     https://www.rottentomatoes.com/m/batman_begins         41          85%
# 26     https://www.rottentomatoes.com/m/batman_begins         41          85%
# 53  https://www.rottentomatoes.com/m/1142872-sky_high         71          73%
# 54  https://www.rottentomatoes.com/m/1142872-sky_high         71          73%
# 55  https://www.rottentomatoes.com/m/1142872-sky_high         71          73%
# 56  https://www.rottentomatoes.com/m/1142872-sky_high         71          73%
#
#    audience_score  rating                                              quote  \
# 2             94%     4.0           Finally!  One worth watching over again!
# 3             94%     1.0  I know it's abotu batman and all, but this mov...
# 4             94%     5.0                      The best Batman movie to date
# 5             94%     4.0  a batman film that didn't let me down, impress...
# 6             94%     5.0  holy crap! best batman movie yet!!!! LOVE IT!!...
# 7             94%     5.0  I don't mean to knock Tim Burton but this was ...
# 8             94%     4.0  A return to the dark feel of the original, and...
# 9             94%     5.0   le meilleur film de batman jusqu'à maintenant...
# 10            94%     5.0  The best and only worthy superhero movie since...
# 11            94%     4.0   i was very impressed with this movie! GO BATMAN!
# 12            94%     4.0  I really enjoyed this one--- alot of action an...
# 13            94%     5.0                              really really good...
# 14            94%     4.0  Terrific superhero movie.  If Nolan didn't dis...
# 15            94%     5.0  After enduring the Joel Schumacher campfests, ...
# 16            94%     5.0  Sin City may be the wildest, but this is the b...
# 17            94%     5.0                 wow, they made a good batman film!
# 18            94%     5.0  Quite Possibly the best comic book movie to date.
# 19            94%     5.0  The best comic book adaption to date. I was ne...
# 20            94%     5.0                          best batman movie to date
# 21            94%     4.0       Very good batman. Has good acting and story.
# 22            94%     5.0  amazing. i loved everything about it...acting,...
# 23            94%     4.0               The best of the Batman movies by far
# 24            94%     5.0                      this is a really good one too
# 25            94%     5.0  Christian Bale is quite possibly the world's b...
# 26            94%     5.0                            Best of the Batman yet.
# 53            57%     4.0                    Very cool, i loved it very much
# 54            57%     4.0  Like have you ever wondered where teens with s...
# 55            57%     2.0  This movie combines really terrible costumes, ...
# 56            57%     4.0  This was a surprising movie. I thought it was ...
#
#    reviewId  isVerified  isSuperReviewer  hasSpoilers  hasProfanity  score  \
# 2       NaN       False            False        False         False    4.0
# 3       NaN       False            False        False         False    1.0
# 4       NaN       False            False        False         False    5.0
# 5       NaN       False            False        False         False    4.0
# 6       NaN       False            False        False         False    5.0
# 7       NaN       False            False        False         False    5.0
# 8       NaN       False            False        False         False    4.0
# 9       NaN       False            False        False         False    5.0
# 10      NaN       False            False        False         False    5.0
# 11      NaN       False            False        False         False    4.0
# 12      NaN       False            False        False         False    4.0
# 13      NaN       False            False        False         False    5.0
# 14      NaN       False            False        False         False    4.0
# 15      NaN       False            False        False         False    5.0
# 16      NaN       False            False        False         False    5.0
# 17      NaN       False            False        False         False    5.0
# 18      NaN       False            False        False         False    5.0
# 19      NaN       False            False        False         False    5.0
# 20      NaN       False            False        False         False    5.0
# 21      NaN       False            False        False         False    4.0
# 22      NaN       False            False        False         False    5.0
# 23      NaN       False            False        False         False    4.0
# 24      NaN       False            False        False         False    5.0
# 25      NaN       False            False        False         False    5.0
# 26      NaN       False            False        False         False    5.0
# 53      NaN       False            False        False         False    4.0
# 54      NaN       False            False        False         False    4.0
# 55      NaN       False            False        False         False    2.0
# 56      NaN       False            False        False         False    4.0
#
#    creationDate  userDisplayName userRealm    userId
# 2    2006-02-10              NaN        RT  23716534
# 3    2006-02-10              NaN        RT  37225455
# 4    2006-02-10              NaN        RT  39217567
# 5    2006-02-10              NaN        RT  44832320
# 6    2006-02-10              NaN        RT  43482784
# 7    2006-02-10              NaN        RT  11675167
# 8    2006-02-10              NaN        RT  37717442
# 9    2006-02-10              NaN        RT  35099457
# 10   2006-02-10              NaN        RT  38236390
# 11   2006-02-10              NaN        RT  34133180
# 12   2006-02-10              NaN        RT  12613494
# 13   2006-02-10              NaN        RT  12572333
# 14   2006-02-10              NaN        RT  40092573
# 15   2006-02-10              NaN        RT  10785783
# 16   2006-02-10              NaN        RT  36794864
# 17   2006-02-10              NaN        RT  45649050
# 18   2006-02-10              NaN        RT  38290051
# 19   2006-02-10              NaN        RT  25267830
# 20   2006-02-10              NaN        RT  44096484
# 21   2006-02-11              NaN        RT  47770119
# 22   2006-02-11              NaN        RT  46139054
# 23   2006-02-11              NaN        RT  30007271
# 24   2006-02-11              NaN        RT  39057216
# 25   2006-02-11              NaN        RT  46807420
# 26   2006-02-11              NaN        RT  25052499
# 53   2006-02-10              NaN        RT  40923588
# 54   2006-02-10              NaN        RT  40446206
# 55   2006-02-10              NaN        RT  44096484
# 56   2006-02-10              NaN        RT  11675167

# %%
cond = movie_review['movieYear'] == 2005
movie_review.loc[cond, 'rating'].mean()
# Out:
# np.float64(4.379310344827586)
